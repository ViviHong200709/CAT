# %%
def str2arr(a):
    a=a.split("	")
    return [float(i) for i in a]

# %%
import matplotlib.pyplot as plt
import numpy as np

max_len = 20
X=np.linspace(1,max_len,max_len)
Y1 = str2arr('0.584806681	0.602517247	0.637088001	0.6720469	0.704297185	0.733481705	0.759352803	0.784405231	0.804532409	0.813421488	0.824444473	0.837267995	0.838254988	0.848931491	0.852530956	0.855508566	0.85771364	0.860074937	0.861531615	0.865651011	0.866122723')
Y2 = str2arr('0.584806681	0.612816036	0.648380518	0.675599456	0.711663723	0.74431777	0.754247069	0.775795758	0.795762777	0.808767259	0.821786642	0.826455653	0.837426245	0.846687317	0.85095197	0.856557071	0.859735966	0.863489628	0.865236282	0.865758896	0.867662251')
Y3 = str2arr('0.584806681	0.616161227	0.651273906	0.68133229	0.717448533	0.749885201	0.772416294	0.79704535	0.812722564	0.821022391	0.831235528	0.839269578	0.846929908	0.852016449	0.853692353	0.855141163	0.857674062	0.859952688	0.862827241	0.863561869	0.863165259')
# Y3 = str2arr('0.584806681	0.613952458	0.643498123	0.676079392	0.700413227	0.73119086	0.75669378	0.778260946	0.792838216	0.807304561	0.819189131	0.831198812	0.836300552	0.843030453	0.848933518	0.851866007	0.856553376	0.860120535	0.862245917	0.864159763	0.863639235')
# plt.plot(X,Y,lable="$sin(X)$",color="red",linewidth=2)

plt.figure(figsize=(8,6))  # 定义图的大小
plt.xlabel("question nums")
plt.ylabel("ACC")
plt.title("Junyi")

plt.plot(X,Y1[1:max_len+1],label='Random')
plt.plot(X,Y2[1:max_len+1],label='vanilla MFI')
plt.plot(X,Y3[1:max_len+1],label='distill-balltree MFI')
plt.legend(loc='lower right')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

max_len = 20
X=np.linspace(1,max_len,max_len)
Y1 = str2arr('0.706048191	0.707743585	0.710925162	0.714518428	0.716999292	0.718899131	0.721063018	0.723703742	0.724972427	0.725895584	0.727624893	0.727101862	0.725075781	0.725616038	0.726116955	0.72606045	0.726865172	0.727198005	0.727070212	0.725883543	0.725289285')
Y2 = str2arr('0.706048191	0.709045768	0.713046968	0.716015339	0.719861805	0.722869694	0.723553836	0.725343645	0.726969242	0.728087485	0.729672074	0.728964508	0.730206847	0.730900943	0.73154372	0.731794775	0.732303441	0.7322824	0.732049048	0.73110503	0.731172323')
Y3 = str2arr('0.706048191	0.709455252	0.712997913	0.716391385	0.719586909	0.722143769	0.724253774	0.725351334	0.726111233	0.727922857	0.727972627	0.728149593	0.728687048	0.729654074	0.73009789	0.730351627	0.730060935	0.730253994	0.730147004	0.729928553	0.728784502')
# Y3 = str2arr('0.584806681	0.613952458	0.643498123	0.676079392	0.700413227	0.73119086	0.75669378	0.778260946	0.792838216	0.807304561	0.819189131	0.831198812	0.836300552	0.843030453	0.848933518	0.851866007	0.856553376	0.860120535	0.862245917	0.864159763	0.863639235')
# plt.plot(X,Y,lable="$sin(X)$",color="red",linewidth=2)

plt.figure(figsize=(8,6))  # 定义图的大小
plt.xlabel("question nums")
plt.ylabel("AUC")
plt.title("Junyi")

plt.plot(X,Y1[1:max_len+1],label='Random')
plt.plot(X,Y2[1:max_len+1],label='vanilla MFI')
plt.plot(X,Y3[1:max_len+1],label='distill-balltree MFI')
plt.legend(loc='lower right')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

max_len = 20
X=np.linspace(1,max_len,max_len)
Y1 = str2arr('0.706048191	0.707743585	0.710925162	0.714518428	0.716999292	0.718899131	0.721063018	0.723703742	0.724972427	0.725895584	0.727624893	0.727101862	0.725075781	0.725616038	0.726116955	0.72606045	0.726865172	0.727198005	0.727070212	0.725883543	0.725289285')
Y2 = str2arr('0.706048191	0.709045768	0.713046968	0.716015339	0.719861805	0.722869694	0.723553836	0.725343645	0.726969242	0.728087485	0.729672074	0.728964508	0.730206847	0.730900943	0.73154372	0.731794775	0.732303441	0.7322824	0.732049048	0.73110503	0.731172323')
Y3 = str2arr('0.706048191	0.709455252	0.712997913	0.716391385	0.719586909	0.722143769	0.724253774	0.725351334	0.726111233	0.727922857	0.727972627	0.728149593	0.728687048	0.729654074	0.73009789	0.730351627	0.730060935	0.730253994	0.730147004	0.729928553	0.728784502')
# Y3 = str2arr('0.584806681	0.613952458	0.643498123	0.676079392	0.700413227	0.73119086	0.75669378	0.778260946	0.792838216	0.807304561	0.819189131	0.831198812	0.836300552	0.843030453	0.848933518	0.851866007	0.856553376	0.860120535	0.862245917	0.864159763	0.863639235')
# plt.plot(X,Y,lable="$sin(X)$",color="red",linewidth=2)

plt.figure(figsize=(8,6))  # 定义图的大小
plt.xlabel("question nums")
plt.ylabel("AUC")
plt.title("Junyi")

plt.plot(X,Y1[1:max_len+1],label='Random')
plt.plot(X,Y2[1:max_len+1],label='vanilla MFI')
plt.plot(X,Y3[1:max_len+1],label='distill-balltree MFI')
plt.legend(loc='lower right')
plt.show()

# %%
max_len = 20
X=np.linspace(1,max_len,max_len)
Y1 = str2arr('0	0.008716566	0.018085696	0.026923563	0.036040653	0.046355523	0.056699961	0.067134298	0.077214308	0.087683566	0.098214388	0.108405612	0.118439354	0.128301218	0.137663856	0.147534579	0.156890303	0.166837573	0.176878437	0.186991796	0.197309077')
Y2 = str2arr('0	0.334779918	0.658797979	1.0049721	1.350464821	1.74174571	2.09875226	2.433509111	2.788253546	3.11843133	3.452255964	3.784145594	4.114686966	4.482792854	4.859811306	5.204447746	5.536699295	5.867616177	6.229877472	6.581305027	6.925681591')
Y3 = str2arr('0	0.021361999	0.035517085	0.054709829	0.072235562	0.096574128	0.134486958	0.16125825	0.197775856	0.233507007	0.279138029	0.332088917	0.393651515	0.453514725	0.513271928	0.570556462	0.623888612	0.679024518	0.738013208	0.795065582	0.853255212')
# Y3 = str2arr('0.584806681	0.613952458	0.643498123	0.676079392	0.700413227	0.73119086	0.75669378	0.778260946	0.792838216	0.807304561	0.819189131	0.831198812	0.836300552	0.843030453	0.848933518	0.851866007	0.856553376	0.860120535	0.862245917	0.864159763	0.863639235')
# plt.plot(X,Y,lable="$sin(X)$",color="red",linewidth=2)

plt.figure(figsize=(8,6))  # 定义图的大小
plt.xlabel("question nums")
plt.ylabel("Time")
plt.title("Junyi")

plt.plot(X,Y1[1:max_len+1],label='Random')
plt.plot(X,Y2[1:max_len+1],label='vanilla MFI')
plt.plot(X,Y3[1:max_len+1],label='distill-balltree MFI')
plt.legend(loc='lower right')
plt.show()

# %%
max_len = 20
X=np.linspace(1,max_len,max_len)
Y1 = str2arr('0.632362425	0.63754046	0.642072082	0.636875868	0.64075017	0.638063133	0.640945315	0.64237088	0.643231094	0.649085939	0.64578402	0.644181907	0.646287143	0.643514693	0.649035096	0.64674437	0.644240201	0.642743468	0.644732773	0.646613359	0.644025922')
Y2 = str2arr('0.632362425	0.646665633	0.642169952	0.651960552	0.653726518	0.656977713	0.659094453	0.659796715	0.659527719	0.658835471	0.66095978	0.663845658	0.661776245	0.664737463	0.666231692	0.668585241	0.671850085	0.667316794	0.671844482	0.670682311	0.672343969')
Y3 = str2arr('0.632362425	0.645125926	0.641368449	0.651960552	0.652180076	0.656833947	0.658257782	0.659486175	0.660275161	0.659362376	0.662153304	0.663547039	0.662682712	0.66505599	0.666316092	0.668250144	0.672151506	0.667625725	0.6715976	0.669707119	0.671219528')
# Y3 = str2arr('0.584806681	0.613952458	0.643498123	0.676079392	0.700413227	0.73119086	0.75669378	0.778260946	0.792838216	0.807304561	0.819189131	0.831198812	0.836300552	0.843030453	0.848933518	0.851866007	0.856553376	0.860120535	0.862245917	0.864159763	0.863639235')
# plt.plot(X,Y,lable="$sin(X)$",color="red",linewidth=2)

plt.figure(figsize=(8,6))  # 定义图的大小
plt.xlabel("question nums")
plt.ylabel("ACC")
plt.title("Assistment")

plt.plot(X,Y1[1:max_len+1],label='Random')
plt.plot(X,Y2[1:max_len+1],label='vanilla MFI')
plt.plot(X,Y3[1:max_len+1],label='distill-balltree MFI')
plt.legend(loc='lower right')
plt.show()

# %%
max_len = 20
X=np.linspace(1,max_len,max_len)
Y1 = str2arr('0.662635088	0.663234293	0.666153669	0.664999723	0.662698925	0.661314607	0.660307765	0.660894096	0.660775542	0.660384059	0.657789052	0.654086649	0.652807295	0.650103152	0.651735187	0.64807117	0.645037711	0.642986476	0.643112957	0.643556654	0.641088963')
Y2 = str2arr('0.662635088	0.666216433	0.663990319	0.66707617	0.669290543	0.667247593	0.668730974	0.668124735	0.669378579	0.669646919	0.669251025	0.667656124	0.666584313	0.668971598	0.669358611	0.670357704	0.671206772	0.675716639	0.674354255	0.674627841	0.674979329')
Y3 = str2arr('0.662635088	0.66583997	0.663679183	0.667063057	0.667803109	0.667152345	0.668843925	0.667509377	0.668990791	0.668044686	0.668366134	0.66777873	0.666897774	0.66888994	0.669598997	0.670918882	0.671863616	0.674573183	0.673139334	0.673680186	0.674108088')
# Y3 = str2arr('0.584806681	0.613952458	0.643498123	0.676079392	0.700413227	0.73119086	0.75669378	0.778260946	0.792838216	0.807304561	0.819189131	0.831198812	0.836300552	0.843030453	0.848933518	0.851866007	0.856553376	0.860120535	0.862245917	0.864159763	0.863639235')
# plt.plot(X,Y,lable="$sin(X)$",color="red",linewidth=2)

plt.figure(figsize=(8,6))  # 定义图的大小
plt.xlabel("question nums")
plt.ylabel("AUC")
plt.title("Assistment")

plt.plot(X,Y1[1:max_len+1],label='Random')
plt.plot(X,Y2[1:max_len+1],label='vanilla MFI')
plt.plot(X,Y3[1:max_len+1],label='distill-balltree MFI')
plt.legend(loc='lower right')
plt.show()

# %%
max_len = 20
X=np.linspace(1,max_len,max_len)
Y1 = str2arr('0	0.010321978	0.020887999	0.032088172	0.043606557	0.055121005	0.06578064	0.076537527	0.087394342	0.098135523	0.108823128	0.119599193	0.131337017	0.142012581	0.152908817	0.163393855	0.173943475	0.184520066	0.195321798	0.205718532	0.216103226')
Y2 = str2arr('0	0.196470946	0.393746346	0.586618602	0.783350348	0.971286535	1.159698963	1.344071865	1.531038284	1.729140878	1.93106842	2.128567696	2.321826935	2.512216091	2.697324514	2.878705263	3.060353041	3.231464863	3.412439823	3.589575529	3.769187212')
Y3 = str2arr('0	0.017691277	0.036551595	0.069557279	0.121960871	0.184999898	0.243621454	0.309155554	0.386382014	0.477397174	0.567904353	0.660592318	0.75655067	0.840204179	0.928118467	1.016612172	1.102485657	1.1866889	1.27028954	1.365132451	1.454950809')
# Y3 = str2arr('0.584806681	0.613952458	0.643498123	0.676079392	0.700413227	0.73119086	0.75669378	0.778260946	0.792838216	0.807304561	0.819189131	0.831198812	0.836300552	0.843030453	0.848933518	0.851866007	0.856553376	0.860120535	0.862245917	0.864159763	0.863639235')
# plt.plot(X,Y,lable="$sin(X)$",color="red",linewidth=2)

plt.figure(figsize=(8,6))  # 定义图的大小
plt.xlabel("question nums")
plt.ylabel("Time")
plt.title("Assistment")

plt.plot(X,Y1[1:max_len+1],label='Random')
plt.plot(X,Y2[1:max_len+1],label='vanilla MFI')
plt.plot(X,Y3[1:max_len+1],label='distill-balltree MFI')
plt.legend(loc='lower right')
plt.show()
